# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# Set variables
# Empty list to hold the cities
cities = []
# URL to pull the API data
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "% Humidity": city_humidity,
                          "% Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | yulara
# Processing Record 4 of Set 1 | houma
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | coihaique
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | lahij
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | amahai
# Processing Record 15 of Set 1 | davila
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | pundaguitan
# Processing Record 18 of Set 1 | haines junction
# Processing Record 19 of Set 1 | kwidzyn
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | chokurdakh
# Processing Record 22 of Set 1 | hambantota
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | nauta
# Processing Record 25 of Set 1 | balkhash
# Processing Record 26 of Set 1 | butaritari
# Processing Record 27 of Set 1 | comodoro rivadavia
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | okhotsk
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | gravdal
# Processing Record 33 of Set 1 | aklavik
# Processing Record 34 of Set 1 | bengkulu
# Processing Record 35 of Set 1 | rockwall
# Processing Record 36 of Set 1 | thayetmyo
# Processing Record 37 of Set 1 | telemaco borba
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | kuandian
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | geraldton
# Processing Record 42 of Set 1 | kodiak
# Processing Record 43 of Set 1 | ishinomaki
# Processing Record 44 of Set 1 | kashan
# Processing Record 45 of Set 1 | port hedland
# Processing Record 46 of Set 1 | chase
# Processing Record 47 of Set 1 | port-cartier
# Processing Record 48 of Set 1 | negombo
# Processing Record 49 of Set 1 | saldanha
# Processing Record 50 of Set 1 | filingue
# Processing Record 1 of Set 2 | kavieng
# Processing Record 2 of Set 2 | santa rita
# Processing Record 3 of Set 2 | teya
# Processing Record 4 of Set 2 | meulaboh
# Processing Record 5 of Set 2 | fort nelson
# Processing Record 6 of Set 2 | saint-francois
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | lebu
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | leopold
# Processing Record 12 of Set 2 | northam
# Processing Record 13 of Set 2 | muli
# Processing Record 14 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 15 of Set 2 | flinders
# Processing Record 16 of Set 2 | klaksvik
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | guarapari
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | luanda
# Processing Record 21 of Set 2 | srednekolymsk
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 2 | pimentel
# Processing Record 25 of Set 2 | jarocin
# Processing Record 26 of Set 2 | rabak
# Processing Record 27 of Set 2 | sao joao da barra
# Processing Record 28 of Set 2 | casper
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | ponta do sol
# Processing Record 31 of Set 2 | mahajanga
# Processing Record 32 of Set 2 | riaba
# City not found. Skipping...
# Processing Record 33 of Set 2 | sibu
# Processing Record 34 of Set 2 | kalmunai
# Processing Record 35 of Set 2 | richards bay
# Processing Record 36 of Set 2 | khonsa
# Processing Record 37 of Set 2 | havre-saint-pierre
# Processing Record 38 of Set 2 | mutsu
# Processing Record 39 of Set 2 | marolambo
# Processing Record 40 of Set 2 | grindavik
# Processing Record 41 of Set 2 | tilichiki
# Processing Record 42 of Set 2 | cabo san lucas
# Processing Record 43 of Set 2 | tuatapere
# Processing Record 44 of Set 2 | bristol
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | hobart
# Processing Record 47 of Set 2 | terrace
# Processing Record 48 of Set 2 | caravelas
# Processing Record 49 of Set 2 | along
# Processing Record 50 of Set 2 | tiksi
# Processing Record 1 of Set 3 | deneysville
# Processing Record 2 of Set 3 | port elizabeth
# Processing Record 3 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 3 | gondanglegi
# Processing Record 5 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 3 | pisco
# Processing Record 7 of Set 3 | upernavik
# Processing Record 8 of Set 3 | alta floresta
# Processing Record 9 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 3 | cidreira
# Processing Record 11 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 3 | mao
# Processing Record 13 of Set 3 | nanortalik
# Processing Record 14 of Set 3 | lanzhou
# Processing Record 15 of Set 3 | new norfolk
# Processing Record 16 of Set 3 | quzhou
# Processing Record 17 of Set 3 | thompson
# Processing Record 18 of Set 3 | hasaki
# Processing Record 19 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 3 | ilulissat
# Processing Record 21 of Set 3 | kudahuvadhoo
# Processing Record 22 of Set 3 | estelle
# Processing Record 23 of Set 3 | souillac
# Processing Record 24 of Set 3 | san cristobal
# Processing Record 25 of Set 3 | tolaga bay
# Processing Record 26 of Set 3 | tuktoyaktuk
# Processing Record 27 of Set 3 | kasongo-lunda
# Processing Record 28 of Set 3 | guerrero negro
# Processing Record 29 of Set 3 | mutis
# Processing Record 30 of Set 3 | whitehaven
# Processing Record 31 of Set 3 | rikitea
# Processing Record 32 of Set 3 | salalah
# Processing Record 33 of Set 3 | anadyr
# Processing Record 34 of Set 3 | acarau
# Processing Record 35 of Set 3 | barrow
# Processing Record 36 of Set 3 | jamestown
# Processing Record 37 of Set 3 | betanzos
# Processing Record 38 of Set 3 | remedios
# Processing Record 39 of Set 3 | codrington
# Processing Record 40 of Set 3 | lompoc
# Processing Record 41 of Set 3 | villa bruzual
# Processing Record 42 of Set 3 | basse
# Processing Record 43 of Set 3 | burgeo
# Processing Record 44 of Set 3 | santa isabel do rio negro
# Processing Record 45 of Set 3 | kapaa
# Processing Record 46 of Set 3 | nador
# Processing Record 47 of Set 3 | oksfjord
# Processing Record 48 of Set 3 | acapulco
# Processing Record 49 of Set 3 | brigantine
# Processing Record 50 of Set 3 | abu kamal
# Processing Record 1 of Set 4 | mar del plata
# Processing Record 2 of Set 4 | letlhakeng
# Processing Record 3 of Set 4 | port alfred
# Processing Record 4 of Set 4 | bambous virieux
# Processing Record 5 of Set 4 | merauke
# Processing Record 6 of Set 4 | sabang
# Processing Record 7 of Set 4 | bethel
# Processing Record 8 of Set 4 | havoysund
# Processing Record 9 of Set 4 | kruisfontein
# Processing Record 10 of Set 4 | dawei
# Processing Record 11 of Set 4 | dingle
# Processing Record 12 of Set 4 | kimbe
# Processing Record 13 of Set 4 | mahebourg
# Processing Record 14 of Set 4 | kenai
# Processing Record 15 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 4 | hermanus
# Processing Record 17 of Set 4 | lata
# Processing Record 18 of Set 4 | east london
# Processing Record 19 of Set 4 | at-bashi
# Processing Record 20 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 4 | ahipara
# Processing Record 22 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 23 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 4 | aleksandrovskoye
# Processing Record 25 of Set 4 | khatanga
# Processing Record 26 of Set 4 | skibbereen
# Processing Record 27 of Set 4 | marzuq
# Processing Record 28 of Set 4 | mersing
# Processing Record 29 of Set 4 | verkhnyaya inta
# Processing Record 30 of Set 4 | veraval
# Processing Record 31 of Set 4 | jhelum
# Processing Record 32 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 4 | kaa-khem
# Processing Record 34 of Set 4 | biankouma
# Processing Record 35 of Set 4 | tres picos
# Processing Record 36 of Set 4 | oranjemund
# Processing Record 37 of Set 4 | matagami
# Processing Record 38 of Set 4 | dunmore town
# Processing Record 39 of Set 4 | boa vista
# Processing Record 40 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 4 | priekule
# Processing Record 42 of Set 4 | saint-philippe
# Processing Record 43 of Set 4 | necochea
# Processing Record 44 of Set 4 | karratha
# Processing Record 45 of Set 4 | vila
# Processing Record 46 of Set 4 | guantanamo
# Processing Record 47 of Set 4 | batsfjord
# Processing Record 48 of Set 4 | kungurtug
# Processing Record 49 of Set 4 | rumilly
# Processing Record 50 of Set 4 | porto santo
# Processing Record 1 of Set 5 | fairbanks
# Processing Record 2 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 5 | fuerte olimpo
# Processing Record 4 of Set 5 | bonavista
# Processing Record 5 of Set 5 | jiwani
# Processing Record 6 of Set 5 | tambura
# Processing Record 7 of Set 5 | sarnen
# Processing Record 8 of Set 5 | esperance
# Processing Record 9 of Set 5 | vostok
# Processing Record 10 of Set 5 | diamantino
# Processing Record 11 of Set 5 | tasiilaq
# Processing Record 12 of Set 5 | torbay
# Processing Record 13 of Set 5 | makasar
# Processing Record 14 of Set 5 | surt
# Processing Record 15 of Set 5 | crib point
# Processing Record 16 of Set 5 | te anau
# Processing Record 17 of Set 5 | quatre cocos
# Processing Record 18 of Set 5 | saint anthony
# Processing Record 19 of Set 5 | byron bay
# Processing Record 20 of Set 5 | georgetown
# Processing Record 21 of Set 5 | gold coast
# Processing Record 22 of Set 5 | vastervik
# City not found. Skipping...
# Processing Record 23 of Set 5 | thenzawl
# Processing Record 24 of Set 5 | shingu
# Processing Record 25 of Set 5 | san patricio
# Processing Record 26 of Set 5 | provideniya
# Processing Record 27 of Set 5 | vila velha
# Processing Record 28 of Set 5 | kavaratti
# Processing Record 29 of Set 5 | rancho palos verdes
# Processing Record 30 of Set 5 | isangel
# Processing Record 31 of Set 5 | baykit
# Processing Record 32 of Set 5 | margate
# Processing Record 33 of Set 5 | castro
# Processing Record 34 of Set 5 | bang mun nak
# Processing Record 35 of Set 5 | faya
# Processing Record 36 of Set 5 | tabuk
# Processing Record 37 of Set 5 | namibe
# Processing Record 38 of Set 5 | gat
# Processing Record 39 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 5 | jalu
# Processing Record 41 of Set 5 | vardo
# Processing Record 42 of Set 5 | ust-kuyga
# Processing Record 43 of Set 5 | gambiran
# Processing Record 44 of Set 5 | zhangjiakou
# Processing Record 45 of Set 5 | kaitangata
# Processing Record 46 of Set 5 | dalvik
# Processing Record 47 of Set 5 | luderitz
# Processing Record 48 of Set 5 | inuvik
# Processing Record 49 of Set 5 | watertown
# Processing Record 50 of Set 5 | vernon
# Processing Record 1 of Set 6 | birmitrapur
# Processing Record 2 of Set 6 | tiznit
# Processing Record 3 of Set 6 | namwala
# Processing Record 4 of Set 6 | bambanglipuro
# Processing Record 5 of Set 6 | bow island
# Processing Record 6 of Set 6 | umm lajj
# Processing Record 7 of Set 6 | tessalit
# Processing Record 8 of Set 6 | pringsewu
# Processing Record 9 of Set 6 | ambon
# Processing Record 10 of Set 6 | saint-joseph
# Processing Record 11 of Set 6 | rincon
# Processing Record 12 of Set 6 | antsohihy
# Processing Record 13 of Set 6 | severo-kurilsk
# Processing Record 14 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 15 of Set 6 | faanui
# Processing Record 16 of Set 6 | ternate
# Processing Record 17 of Set 6 | hovd
# Processing Record 18 of Set 6 | vilhena
# Processing Record 19 of Set 6 | port lincoln
# Processing Record 20 of Set 6 | birjand
# Processing Record 21 of Set 6 | kaeo
# Processing Record 22 of Set 6 | jiaojiang
# Processing Record 23 of Set 6 | cap malheureux
# Processing Record 24 of Set 6 | havelock
# Processing Record 25 of Set 6 | fremont
# Processing Record 26 of Set 6 | westport
# Processing Record 27 of Set 6 | puerto escondido
# Processing Record 28 of Set 6 | lazo
# Processing Record 29 of Set 6 | la tuque
# Processing Record 30 of Set 6 | assiniboia
# Processing Record 31 of Set 6 | narsaq
# Processing Record 32 of Set 6 | vrchlabi
# Processing Record 33 of Set 6 | lavrentiya
# Processing Record 34 of Set 6 | mizan teferi
# Processing Record 35 of Set 6 | husavik
# Processing Record 36 of Set 6 | chanika
# Processing Record 37 of Set 6 | iqaluit
# Processing Record 38 of Set 6 | alofi
# Processing Record 39 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 6 | plettenberg bay
# Processing Record 41 of Set 6 | englewood
# Processing Record 42 of Set 6 | beringovskiy
# Processing Record 43 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 44 of Set 6 | bluff
# Processing Record 45 of Set 6 | horni slavkov
# Processing Record 46 of Set 6 | moree
# Processing Record 47 of Set 6 | deputatskiy
# Processing Record 48 of Set 6 | rio gallegos
# Processing Record 49 of Set 6 | nome
# Processing Record 50 of Set 6 | itarantim
# Processing Record 1 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 7 | keansburg
# Processing Record 4 of Set 7 | los llanos de aridane
# Processing Record 5 of Set 7 | auki
# Processing Record 6 of Set 7 | fortuna
# Processing Record 7 of Set 7 | ondjiva
# Processing Record 8 of Set 7 | port augusta
# Processing Record 9 of Set 7 | payo
# Processing Record 10 of Set 7 | green valley
# Processing Record 11 of Set 7 | kaduna
# Processing Record 12 of Set 7 | goderich
# Processing Record 13 of Set 7 | banjarmasin
# Processing Record 14 of Set 7 | sosnovoborsk
# Processing Record 15 of Set 7 | san quintin
# Processing Record 16 of Set 7 | lagoa
# Processing Record 17 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 18 of Set 7 | madison
# Processing Record 19 of Set 7 | sitka
# Processing Record 20 of Set 7 | hofn
# Processing Record 21 of Set 7 | yatou
# Processing Record 22 of Set 7 | camacha
# Processing Record 23 of Set 7 | port-gentil
# Processing Record 24 of Set 7 | crixas
# Processing Record 25 of Set 7 | alexandria
# Processing Record 26 of Set 7 | bernay
# Processing Record 27 of Set 7 | olafsvik
# Processing Record 28 of Set 7 | topolovgrad
# Processing Record 29 of Set 7 | gornouralskiy
# City not found. Skipping...
# Processing Record 30 of Set 7 | wick
# Processing Record 31 of Set 7 | burica
# City not found. Skipping...
# Processing Record 32 of Set 7 | lorengau
# Processing Record 33 of Set 7 | victoria
# Processing Record 34 of Set 7 | zheshart
# Processing Record 35 of Set 7 | saint-louis
# Processing Record 36 of Set 7 | mataram
# Processing Record 37 of Set 7 | miracema do tocantins
# Processing Record 38 of Set 7 | naze
# Processing Record 39 of Set 7 | malino
# Processing Record 40 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 7 | pasighat
# Processing Record 42 of Set 7 | katsiveli
# City not found. Skipping...
# Processing Record 43 of Set 7 | xapuri
# Processing Record 44 of Set 7 | sobolevo
# Processing Record 45 of Set 7 | norman wells
# Processing Record 46 of Set 7 | nhulunbuy
# Processing Record 47 of Set 7 | hirara
# Processing Record 48 of Set 7 | bandar
# Processing Record 49 of Set 7 | portland
# Processing Record 50 of Set 7 | hervey bay
# Processing Record 1 of Set 8 | cruz
# Processing Record 2 of Set 8 | padang
# Processing Record 3 of Set 8 | talnakh
# Processing Record 4 of Set 8 | buchanan
# Processing Record 5 of Set 8 | roma
# Processing Record 6 of Set 8 | grand gaube
# Processing Record 7 of Set 8 | qingdao
# Processing Record 8 of Set 8 | coahuayana
# Processing Record 9 of Set 8 | ostrovnoy
# Processing Record 10 of Set 8 | toktogul
# Processing Record 11 of Set 8 | ino
# Processing Record 12 of Set 8 | clyde river
# Processing Record 13 of Set 8 | maragogi
# Processing Record 14 of Set 8 | dongying
# Processing Record 15 of Set 8 | shikohabad
# Processing Record 16 of Set 8 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 8 | lichinga
# Processing Record 18 of Set 8 | cayenne
# Processing Record 19 of Set 8 | sao filipe
# Processing Record 20 of Set 8 | nouadhibou
# Processing Record 21 of Set 8 | wuwei
# Processing Record 22 of Set 8 | coquimbo
# Processing Record 23 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 24 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 8 | walvis bay
# Processing Record 26 of Set 8 | kati
# Processing Record 27 of Set 8 | mana
# Processing Record 28 of Set 8 | bonthe
# Processing Record 29 of Set 8 | sault sainte marie
# Processing Record 30 of Set 8 | tautira
# Processing Record 31 of Set 8 | poole
# Processing Record 32 of Set 8 | lethem
# Processing Record 33 of Set 8 | kontagora
# Processing Record 34 of Set 8 | vacaria
# Processing Record 35 of Set 8 | kuytun
# Processing Record 36 of Set 8 | hamilton
# Processing Record 37 of Set 8 | izmalkovo
# Processing Record 38 of Set 8 | henties bay
# Processing Record 39 of Set 8 | bilibino
# Processing Record 40 of Set 8 | carroll
# Processing Record 41 of Set 8 | ukiah
# Processing Record 42 of Set 8 | bastia
# Processing Record 43 of Set 8 | bardiyah
# Processing Record 44 of Set 8 | omboue
# Processing Record 45 of Set 8 | pozo colorado
# Processing Record 46 of Set 8 | cockburn town
# Processing Record 47 of Set 8 | gainesville
# Processing Record 48 of Set 8 | calamar
# Processing Record 49 of Set 8 | birao
# Processing Record 50 of Set 8 | atar
# Processing Record 1 of Set 9 | sinnamary
# Processing Record 2 of Set 9 | marawi
# Processing Record 3 of Set 9 | opuwo
# Processing Record 4 of Set 9 | bidor
# Processing Record 5 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 9 | awbari
# Processing Record 7 of Set 9 | natitingou
# Processing Record 8 of Set 9 | bose
# Processing Record 9 of Set 9 | lagos
# Processing Record 10 of Set 9 | makakilo city
# Processing Record 11 of Set 9 | hendek
# Processing Record 12 of Set 9 | adre
# Processing Record 13 of Set 9 | catamarca
# Processing Record 14 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 9 | chubbuck
# Processing Record 16 of Set 9 | ilembula
# Processing Record 17 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 18 of Set 9 | lodwar
# Processing Record 19 of Set 9 | kahului
# Processing Record 20 of Set 9 | mandan
# Processing Record 21 of Set 9 | zilair
# Processing Record 22 of Set 9 | cherskiy
# Processing Record 23 of Set 9 | aksu
# Processing Record 24 of Set 9 | katsuura
# Processing Record 25 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 9 | kamskiye polyany
# Processing Record 27 of Set 9 | leningradskiy
# Processing Record 28 of Set 9 | mayskiy
# Processing Record 29 of Set 9 | udachnyy
# Processing Record 30 of Set 9 | belmopan
# Processing Record 31 of Set 9 | xuanhua
# Processing Record 32 of Set 9 | manoel urbano
# Processing Record 33 of Set 9 | san carlos de bariloche
# Processing Record 34 of Set 9 | manggar
# Processing Record 35 of Set 9 | omsukchan
# Processing Record 36 of Set 9 | buraydah
# Processing Record 37 of Set 9 | caledon
# Processing Record 38 of Set 9 | fare
# Processing Record 39 of Set 9 | robe
# Processing Record 40 of Set 9 | yerbogachen
# Processing Record 41 of Set 9 | zharkent
# Processing Record 42 of Set 9 | cleburne
# Processing Record 43 of Set 9 | sungaipenuh
# Processing Record 44 of Set 9 | tocopilla
# Processing Record 45 of Set 9 | phan thiet
# Processing Record 46 of Set 9 | pevek
# Processing Record 47 of Set 9 | jian
# Processing Record 48 of Set 9 | eskil
# Processing Record 49 of Set 9 | vienna
# Processing Record 50 of Set 9 | rudbar
# Processing Record 1 of Set 10 | athy
# Processing Record 2 of Set 10 | mount isa
# Processing Record 3 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 10 | khandagayty
# Processing Record 5 of Set 10 | churapcha
# Processing Record 6 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 10 | ust-tsilma
# Processing Record 8 of Set 10 | thinadhoo
# Processing Record 9 of Set 10 | lanxi
# Processing Record 10 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 10 | batagay
# Processing Record 12 of Set 10 | wattegama
# Processing Record 13 of Set 10 | poum
# Processing Record 14 of Set 10 | torri di quartesolo
# Processing Record 15 of Set 10 | ayer itam
# City not found. Skipping...
# Processing Record 16 of Set 10 | urumqi
# Processing Record 17 of Set 10 | litovko
# Processing Record 18 of Set 10 | muzhi
# Processing Record 19 of Set 10 | shilovo
# Processing Record 20 of Set 10 | saskylakh
# Processing Record 21 of Set 10 | atambua
# Processing Record 22 of Set 10 | sisimiut
# Processing Record 23 of Set 10 | sola
# Processing Record 24 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 10 | pangody
# Processing Record 26 of Set 10 | constitucion
# Processing Record 27 of Set 10 | lixourion
# Processing Record 28 of Set 10 | krasnoselkup
# Processing Record 29 of Set 10 | mugur-aksy
# Processing Record 30 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 31 of Set 10 | san luis
# Processing Record 32 of Set 10 | san jeronimo
# Processing Record 33 of Set 10 | orlik
# Processing Record 34 of Set 10 | panaba
# Processing Record 35 of Set 10 | santa lucia
# Processing Record 36 of Set 10 | kiunga
# Processing Record 37 of Set 10 | melfi
# Processing Record 38 of Set 10 | dhidhdhoo
# Processing Record 39 of Set 10 | bowen
# Processing Record 40 of Set 10 | lamar
# Processing Record 41 of Set 10 | yulin
# Processing Record 42 of Set 10 | mabaruma
# Processing Record 43 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 44 of Set 10 | huarmey
# Processing Record 45 of Set 10 | vitim
# Processing Record 46 of Set 10 | pangnirtung
# Processing Record 47 of Set 10 | wageningen
# Processing Record 48 of Set 10 | newport
# Processing Record 49 of Set 10 | yamada
# Processing Record 50 of Set 10 | mumbwa
# Processing Record 1 of Set 11 | buala
# Processing Record 2 of Set 11 | rehoboth
# Processing Record 3 of Set 11 | agirish
# Processing Record 4 of Set 11 | viga
# Processing Record 5 of Set 11 | nyurba
# Processing Record 6 of Set 11 | payson
# Processing Record 7 of Set 11 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 8 of Set 11 | marsh harbour
# Processing Record 9 of Set 11 | eyl
# Processing Record 10 of Set 11 | abaza
# Processing Record 11 of Set 11 | denau
# City not found. Skipping...
# Processing Record 12 of Set 11 | cedar lake
# Processing Record 13 of Set 11 | zhaotong
# Processing Record 14 of Set 11 | berlevag
# Processing Record 15 of Set 11 | shimoda
# Processing Record 16 of Set 11 | gejiu
# Processing Record 17 of Set 11 | buin
# Processing Record 18 of Set 11 | santa cruz
# Processing Record 19 of Set 11 | berdigestyakh
# Processing Record 20 of Set 11 | boyolangu
# Processing Record 21 of Set 11 | chipinge
# Processing Record 22 of Set 11 | san vicente
# Processing Record 23 of Set 11 | kerch
# Processing Record 24 of Set 11 | ponta delgada
# Processing Record 25 of Set 11 | grafton
# Processing Record 26 of Set 11 | lima
# Processing Record 27 of Set 11 | sept-iles
# Processing Record 28 of Set 11 | pacific grove
# Processing Record 29 of Set 11 | pesochnoye
# Processing Record 30 of Set 11 | salinas
# Processing Record 31 of Set 11 | qui nhon
# Processing Record 32 of Set 11 | pemangkat
# Processing Record 33 of Set 11 | yakima
# Processing Record 34 of Set 11 | alice springs
# Processing Record 35 of Set 11 | akhtubinsk
# Processing Record 36 of Set 11 | alpena
# Processing Record 37 of Set 11 | virginia beach
# Processing Record 38 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 11 | salisbury
# Processing Record 40 of Set 11 | burns lake
# Processing Record 41 of Set 11 | colotlan
# Processing Record 42 of Set 11 | salamiyah
# Processing Record 43 of Set 11 | green river
# Processing Record 44 of Set 11 | sabha
# Processing Record 45 of Set 11 | namyslow
# Processing Record 46 of Set 11 | santa cruz de la palma
# Processing Record 47 of Set 11 | tadine
# Processing Record 48 of Set 11 | magadan
# Processing Record 49 of Set 11 | naryan-mar
# Processing Record 50 of Set 11 | bay roberts
# Processing Record 1 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 2 of Set 12 | aloleng
# Processing Record 3 of Set 12 | uruzgan
# Processing Record 4 of Set 12 | hobyo
# Processing Record 5 of Set 12 | kisangani
# Processing Record 6 of Set 12 | tsentralnyy
# City not found. Skipping...
# Processing Record 7 of Set 12 | san juan
# Processing Record 8 of Set 12 | ancud
# Processing Record 9 of Set 12 | spassk-dalniy
# Processing Record 10 of Set 12 | inta
# Processing Record 11 of Set 12 | oktyabrskiy
# Processing Record 12 of Set 12 | beloha
# Processing Record 13 of Set 12 | rurrenabaque
# Processing Record 14 of Set 12 | moa
# Processing Record 15 of Set 12 | wukari
# Processing Record 16 of Set 12 | rio grande
# Processing Record 17 of Set 12 | kavarskas
# Processing Record 18 of Set 12 | linhares
# Processing Record 19 of Set 12 | manaul
# Processing Record 20 of Set 12 | kilindoni
# Processing Record 21 of Set 12 | saint-augustin
# Processing Record 22 of Set 12 | uruacu
# Processing Record 23 of Set 12 | axim
# Processing Record 24 of Set 12 | sovetskiy
# Processing Record 25 of Set 12 | swan hill
# Processing Record 26 of Set 12 | curuguaty
# Processing Record 27 of Set 12 | hokitika
# Processing Record 28 of Set 12 | nakskov
# Processing Record 29 of Set 12 | honningsvag
# Processing Record 30 of Set 12 | talcahuano
# Processing Record 31 of Set 12 | kirakira
# Processing Record 32 of Set 12 | bartica
# Processing Record 33 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 34 of Set 12 | ananindeua
# Processing Record 35 of Set 12 | kutum
# Processing Record 36 of Set 12 | nova prata
# Processing Record 37 of Set 12 | bagru
# Processing Record 38 of Set 12 | develi
# Processing Record 39 of Set 12 | hellvik
# Processing Record 40 of Set 12 | algiers
# Processing Record 41 of Set 12 | muros
# Processing Record 42 of Set 12 | seoul
# Processing Record 43 of Set 12 | garavuti
# Processing Record 44 of Set 12 | kankon
# Processing Record 45 of Set 12 | pangai
# Processing Record 46 of Set 12 | brae
# Processing Record 47 of Set 12 | taoudenni
# Processing Record 48 of Set 12 | togur
# Processing Record 49 of Set 12 | zhukovo
# Processing Record 50 of Set 12 | tual
# Processing Record 1 of Set 13 | agadez
# Processing Record 2 of Set 13 | jawhar
# Processing Record 3 of Set 13 | biltine
# Processing Record 4 of Set 13 | anderson
# Processing Record 5 of Set 13 | paracuru
# Processing Record 6 of Set 13 | college
# Processing Record 7 of Set 13 | sogdiondon
# City not found. Skipping...
# Processing Record 8 of Set 13 | popondetta
# Processing Record 9 of Set 13 | drabiv
# Processing Record 10 of Set 13 | ipixuna
# Processing Record 11 of Set 13 | baracoa
# Processing Record 12 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 13 of Set 13 | altay
# Processing Record 14 of Set 13 | lafia
# Processing Record 15 of Set 13 | damghan
# Processing Record 16 of Set 13 | dandong
# Processing Record 17 of Set 13 | itarema
# Processing Record 18 of Set 13 | sulangan
# Processing Record 19 of Set 13 | staryy nadym
# Processing Record 20 of Set 13 | istisu
# Processing Record 21 of Set 13 | sarana
# Processing Record 22 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 23 of Set 13 | huanan
# Processing Record 24 of Set 13 | dunedin
# Processing Record 25 of Set 13 | kaspiyskiy
# Processing Record 26 of Set 13 | lena
# Processing Record 27 of Set 13 | sakata
# Processing Record 28 of Set 13 | manaus
# Processing Record 29 of Set 13 | kijang
# Processing Record 30 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 13 | dwarka
# Processing Record 32 of Set 13 | orizatlan
# Processing Record 33 of Set 13 | fuxin
# Processing Record 34 of Set 13 | general pico
# Processing Record 35 of Set 13 | aswan
# Processing Record 36 of Set 13 | christchurch
# Processing Record 37 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 13 | saint-pierre
# Processing Record 39 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 13 | mnogovershinnyy
# Processing Record 41 of Set 13 | kloulklubed
# Processing Record 42 of Set 13 | paamiut
# Processing Record 43 of Set 13 | mortka
# Processing Record 44 of Set 13 | tsabong
# Processing Record 45 of Set 13 | darnah
# Processing Record 46 of Set 13 | mehamn
# Processing Record 47 of Set 13 | kushima
# Processing Record 48 of Set 13 | two rivers
# Processing Record 49 of Set 13 | magole
# Processing Record 50 of Set 13 | usinsk
# Processing Record 1 of Set 14 | moerai
# Processing Record 2 of Set 14 | mount gambier
# Processing Record 3 of Set 14 | mildura
# Processing Record 4 of Set 14 | machinga
# Processing Record 5 of Set 14 | kosonsoy
# Processing Record 6 of Set 14 | dubrovka
# Processing Record 7 of Set 14 | dakar
# Processing Record 8 of Set 14 | ilembo
# Processing Record 9 of Set 14 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 10 of Set 14 | bara
# Processing Record 11 of Set 14 | zabalj
# Processing Record 12 of Set 14 | redlands
# Processing Record 13 of Set 14 | broken hill
# Processing Record 14 of Set 14 | anzio
# Processing Record 15 of Set 14 | casablanca
# Processing Record 16 of Set 14 | sao sebastiao
# Processing Record 17 of Set 14 | oum hadjer
# Processing Record 18 of Set 14 | kazerun
# Processing Record 19 of Set 14 | chickasha
# Processing Record 20 of Set 14 | makarska
# Processing Record 21 of Set 14 | san rafael
# Processing Record 22 of Set 14 | abong mbang
# Processing Record 23 of Set 14 | csavoly
# Processing Record 24 of Set 14 | sooke
# Processing Record 25 of Set 14 | les cayes
# Processing Record 26 of Set 14 | sioux lookout
# Processing Record 27 of Set 14 | liku
# Processing Record 28 of Set 14 | wuchi
# Processing Record 29 of Set 14 | colares
# Processing Record 30 of Set 14 | iskateley
# Processing Record 31 of Set 14 | mackay
# Processing Record 32 of Set 14 | esna
# Processing Record 33 of Set 14 | glubokoe
# City not found. Skipping...
# Processing Record 34 of Set 14 | cabra
# Processing Record 35 of Set 14 | praia da vitoria
# Processing Record 36 of Set 14 | timiryazevskoye
# Processing Record 37 of Set 14 | ryotsu
# Processing Record 38 of Set 14 | santa maria do para
# Processing Record 39 of Set 14 | raga
# Processing Record 40 of Set 14 | mporokoso
# Processing Record 41 of Set 14 | takoradi
# Processing Record 42 of Set 14 | grand-santi
# Processing Record 43 of Set 14 | labrea
# Processing Record 44 of Set 14 | kolvereid
# Processing Record 45 of Set 14 | dalbandin
# Processing Record 46 of Set 14 | lazaro cardenas
# Processing Record 47 of Set 14 | miranda de ebro
# Processing Record 48 of Set 14 | ribas do rio pardo
# Processing Record 49 of Set 14 | bousso
# Processing Record 50 of Set 14 | tucumcari
# Processing Record 1 of Set 15 | safford
# Processing Record 2 of Set 15 | mokhsogollokh
# Processing Record 3 of Set 15 | osypenko
# Processing Record 4 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 5 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 15 | bathsheba
# Processing Record 7 of Set 15 | saint-die
# City not found. Skipping...
# Processing Record 8 of Set 15 | mongo
# Processing Record 9 of Set 15 | pavlogradka
# Processing Record 10 of Set 15 | chara
# Processing Record 11 of Set 15 | suhbaatar
# Processing Record 12 of Set 15 | tianpeng
# Processing Record 13 of Set 15 | harwich
# Processing Record 14 of Set 15 | port moresby
# Processing Record 15 of Set 15 | manokwari
# Processing Record 16 of Set 15 | zilupe
# Processing Record 17 of Set 15 | maralal
# Processing Record 18 of Set 15 | saint george
# Processing Record 19 of Set 15 | waipawa
# Processing Record 20 of Set 15 | vestmannaeyjar
# Processing Record 21 of Set 15 | ciudad bolivar
# Processing Record 22 of Set 15 | chepen
# Processing Record 23 of Set 15 | kamenka
# Processing Record 24 of Set 15 | anage
# Processing Record 25 of Set 15 | taunggyi
# Processing Record 26 of Set 15 | zhanaozen
# Processing Record 27 of Set 15 | komsomolskiy
# Processing Record 28 of Set 15 | laguna
# Processing Record 29 of Set 15 | emerald
# Processing Record 30 of Set 15 | kormilovka
# Processing Record 31 of Set 15 | maragua
# Processing Record 32 of Set 15 | grand bank
# Processing Record 33 of Set 15 | mandalgovi
# Processing Record 34 of Set 15 | moose factory
# Processing Record 35 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 36 of Set 15 | enterprise
# Processing Record 37 of Set 15 | uray
# Processing Record 38 of Set 15 | terme
# Processing Record 39 of Set 15 | rosarito
# Processing Record 40 of Set 15 | nemuro
# Processing Record 41 of Set 15 | kathmandu
# Processing Record 42 of Set 15 | el wasta
# City not found. Skipping...
# Processing Record 43 of Set 15 | atakpame
# Processing Record 44 of Set 15 | lasa
# Processing Record 45 of Set 15 | verkhniye sergi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 683

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  % Humidity  % Cloudiness  \
# 0        Dikson  73.5069   80.5464     37.67          99           100
# 1        Yulara -25.2406  130.9889     64.24          48            90
# 2         Houma  29.5958  -90.7195     91.40          75             1
# 3          Chuy -33.6971  -53.4616     42.58          70            11
# 4     Coihaique -45.5752  -72.0662     35.55          93             0
# 5  Longyearbyen  78.2186   15.6401     42.64          93            75
# 6     Carnarvon -24.8667  113.6333     60.87          54            90
# 7       Ushuaia -54.8000  -68.3000     37.06          93            90
# 8    Nikolskoye  59.7035   30.7861     65.01          67           100
# 9         Lahij  13.1667   44.5833     80.01          67            27
#
#    Wind Speed Country                 Date Current Description
# 0       15.19      RU  2021-07-28 00:31:41     overcast clouds
# 1        4.61      AU  2021-07-28 00:31:41     overcast clouds
# 2        9.22      US  2021-07-28 00:31:41           clear sky
# 3       15.95      UY  2021-07-28 00:28:40          few clouds
# 4        2.30      CL  2021-07-28 00:31:28           clear sky
# 5       11.50      SJ  2021-07-28 00:31:42          light rain
# 6        9.22      AU  2021-07-28 00:31:30     overcast clouds
# 7        1.14      AR  2021-07-28 00:29:56          light rain
# 8        4.65      RU  2021-07-28 00:31:42     overcast clouds
# 9        0.98      YE  2021-07-28 00:31:42    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp","% Humidity", "% Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  % Humidity  \
# 0        Dikson      RU  73.5069   80.5464     37.67          99
# 1        Yulara      AU -25.2406  130.9889     64.24          48
# 2         Houma      US  29.5958  -90.7195     91.40          75
# 3          Chuy      UY -33.6971  -53.4616     42.58          70
# 4     Coihaique      CL -45.5752  -72.0662     35.55          93
# 5  Longyearbyen      SJ  78.2186   15.6401     42.64          93
# 6     Carnarvon      AU -24.8667  113.6333     60.87          54
# 7       Ushuaia      AR -54.8000  -68.3000     37.06          93
# 8    Nikolskoye      RU  59.7035   30.7861     65.01          67
# 9         Lahij      YE  13.1667   44.5833     80.01          67
#
#    % Cloudiness  Wind Speed Current Description
# 0           100       15.19     overcast clouds
# 1            90        4.61     overcast clouds
# 2             1        9.22           clear sky
# 3            11       15.95          few clouds
# 4             0        2.30           clear sky
# 5            75       11.50          light rain
# 6            90        9.22     overcast clouds
# 7            90        1.14          light rain
# 8           100        4.65     overcast clouds
# 9            27        0.98    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
